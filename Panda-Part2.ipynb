# %% [markdown]
# # Pandas-Part1

# %% [markdown]
# ## What : means in slices [start:end]
#
# start: where to begin (inclusive)
#
# stop: where to end
#
# .iloc (position-based): end is exclusive
# e.g., df.iloc[0:3] → positions 0,1,2
#
# .loc (label-based): end is inclusive
# e.g., df.loc["A":"C"] → labels A, B, and C

# %%
# Example code to show iloc vs loc
import pandas as pd
df = pd.DataFrame({
    "math": [85, 90, 78, 92],
    "english": [88, 76, 95, 80],
    "science": [91, 89, 84, 77],
    "history": [70, 85, 88, 93]
}, index=["s1", "s2", "s3", "s4"])

df
# Out:
#     math  english  science  history
# s1    85       88       91       70
# s2    90       76       89       85
# s3    78       95       84       88
# s4    92       80       77       93

# %%
# Example code to show iloc vs loc
import pandas as pd
df2 = pd.DataFrame({
    "math": [85, 90, 78, 92],
    "english": [88, 76, 95, 80],
    "science": [91, 89, 84, 77],
    "history": [70, 85, 88, 93]
})

df2
# Out:
#    math  english  science  history
# 0    85       88       91       70
# 1    90       76       89       85
# 2    78       95       84       88
# 3    92       80       77       93

# %%
# mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd #pd is an alias

# %%
# contrl-V for pasting the path!

df = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/6110/GitHub/6110-Fall-2025/Data/dataset2.xlsx", sheet_name = "Restaurant_Reviews")
df  #df is an ref variable pointing to an object of type DataFrame
# DataFrame is a type --> rows x columns
# Out:
#      RecordNum  Ambience  Cleanliness  Service  Food
# 0            1       4.0          5.0      6.0   4.0
# 1            2       6.0          6.0      NaN   6.0
# 2            3       5.0          6.0      6.0   7.0
# 3            4       4.0          7.0      5.0   4.0
# 4            5       4.0          7.0      7.0   4.0
# ..         ...       ...          ...      ...   ...
# 145        146       5.0          6.0      6.0   3.0
# 146        147       4.0          6.0      5.0   6.0
# 147        148       5.0          6.0      7.0   5.0
# 148        149       5.0          5.0      5.0   4.0
# 149        150       3.0          5.0      6.0   7.0
#
# [150 rows x 5 columns]

# %%
df.head()
# Out:
#    RecordNum  Ambience  Cleanliness  Service  Food
# 0          1       4.0          5.0      6.0   4.0
# 1          2       6.0          6.0      NaN   6.0
# 2          3       5.0          6.0      6.0   7.0
# 3          4       4.0          7.0      5.0   4.0
# 4          5       4.0          7.0      7.0   4.0

# %%
df.shape # shape is a very useful attribute available in Pandas package!
#rows x columns
# Out:
# (150, 5)

# %%
df.describe() #describe () is a method avaialble in Pandas package
# Out:
#         RecordNum    Ambience  Cleanliness     Service        Food
# count  150.000000  149.000000   149.000000  147.000000  149.000000
# mean    75.500000    4.429530     5.463087    5.965986    5.080537
# std     43.445368    1.110485     1.056022    0.822750    1.421442
# min      1.000000    3.000000     4.000000    5.000000    3.000000
# 25%     38.250000    3.000000     5.000000    5.000000    4.000000
# 50%     75.500000    4.000000     5.000000    6.000000    5.000000
# 75%    112.750000    5.000000     6.000000    7.000000    6.000000
# max    150.000000    6.000000     7.000000    7.000000    7.000000

# %%
#Sorting

# %%
#Missing Values

# %%
#Row subsetting using boolean expression
